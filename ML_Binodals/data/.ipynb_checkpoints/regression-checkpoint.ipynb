# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2023-09-13 18:59:40.122930: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.12.1

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

# %%
dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %%
dataset.isna().sum()
dataset.dropna()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [392 rows x 8 columns]

# %%
dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})

# %%
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82     USA
# 394          82  Europe
# 395          82     USA
# 396          82     USA
# 397          82     USA

# %%
dataset = pd.get_dummies(dataset, columns=['Origin'], prefix='', prefix_sep='')

# %%
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan    USA
# 393          82   False  False   True
# 394          82    True  False  False
# 395          82   False  False   True
# 396          82   False  False   True
# 397          82   False  False   True

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
test_labels = test_features.pop('MPG')

# %%
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min       25%      50%  \
# MPG           318.0    23.590566    7.913617    10.0    17.125    22.75
# Cylinders     318.0     5.427673    1.682941     3.0     4.000     4.00
# Displacement  318.0   193.061321  103.812742    70.0   100.250   151.00
# Horsepower    313.0   104.067093   38.674662    46.0    75.000    92.00
# Weight        318.0  2963.823899  844.749805  1613.0  2219.250  2792.50
# Acceleration  318.0    15.595912    2.796282     8.0    13.900    15.50
# Model Year    318.0    75.946541    3.705266    70.0    73.000    76.00
#
#                   75%     max
# MPG             29.00    46.6
# Cylinders        6.00     8.0
# Displacement   259.50   455.0
# Horsepower     120.00   230.0
# Weight        3571.25  5140.0
# Acceleration    17.30    24.8
# Model Year      79.00    82.0

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 normalizer = tf.keras.layers.Normalization(axis=-1)
# ----> 2 normalizer.adapt(np.array(train_features))
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/layers/preprocessing/normalization.py:286, in Normalization.adapt(self, data, batch_size, steps)
#     240 def adapt(self, data, batch_size=None, steps=None):
#     241     """Computes the mean and variance of values in a dataset.
#     242
#     243     Calling `adapt()` on a `Normalization` layer is an alternative to
#    (...)
#     284           argument is not supported with array inputs.
#     285     """
# --> 286     super().adapt(data, batch_size=batch_size, steps=steps)
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/engine/base_preprocessing_layer.py:246, in PreprocessingLayer.adapt(self, data, batch_size, steps)
#     244 if self.built:
#     245     self.reset_state()
# --> 246 data_handler = data_adapter.DataHandler(
#     247     data,
#     248     batch_size=batch_size,
#     249     steps_per_epoch=steps,
#     250     epochs=1,
#     251     steps_per_execution=self._steps_per_execution,
#     252     distribute=False,
#     253 )
#     254 self._adapt_function = self.make_adapt_function()
#     255 for _, iterator in data_handler.enumerate_epochs():
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/engine/data_adapter.py:1260, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257     self._steps_per_execution = steps_per_execution
#    1259 adapter_cls = select_data_adapter(x, y)
# -> 1260 self._adapter = adapter_cls(
#    1261     x,
#    1262     y,
#    1263     batch_size=batch_size,
#    1264     steps=steps_per_epoch,
#    1265     epochs=epochs - initial_epoch,
#    1266     sample_weights=sample_weight,
#    1267     shuffle=shuffle,
#    1268     max_queue_size=max_queue_size,
#    1269     workers=workers,
#    1270     use_multiprocessing=use_multiprocessing,
#    1271     distribution_strategy=tf.distribute.get_strategy(),
#    1272     model=model,
#    1273 )
#    1275 strategy = tf.distribute.get_strategy()
#    1277 self._current_step = 0
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/engine/data_adapter.py:246, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     233 def __init__(
#     234     self,
#     235     x,
#    (...)
#     243     **kwargs,
#     244 ):
#     245     super().__init__(x, y, **kwargs)
# --> 246     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     247     sample_weight_modes = broadcast_sample_weight_modes(
#     248         sample_weights, sample_weight_modes
#     249     )
#     251     # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/engine/data_adapter.py:1140, in _process_tensorlike(inputs)
#    1137         return _scipy_sparse_to_sparse_tensor(x)
#    1138     return x
# -> 1140 inputs = tf.nest.map_structure(_convert_single_tensor, inputs)
#    1141 return tf.__internal__.nest.list_to_tuple(inputs)
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/keras/engine/data_adapter.py:1135, in _process_tensorlike.<locals>._convert_single_tensor(x)
#    1133     if issubclass(x.dtype.type, np.floating):
#    1134         dtype = backend.floatx()
# -> 1135     return tf.convert_to_tensor(x, dtype=dtype)
#    1136 elif _is_scipy_sparse(x):
#    1137     return _scipy_sparse_to_sparse_tensor(x)
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/opt/anaconda3/envs/binodal/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())

# %%
np.mean(train_features["Horsepower"])
